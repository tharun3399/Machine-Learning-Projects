# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csvb('HR_comma_sep.csv')

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# %matplotlib inline
plt.scatter(df['satisfaction_level'],df['left'])
plt.xlabel("Satisifaction Level")
# Out:
# Text(0.5, 0, 'Satisifaction Level')

# %%
plt.scatter(df['last_evaluation'],df['left'])
plt.xlabel('last_evaluation')
# Out:
# Text(0.5, 0, 'last_evaluation')

# %%
plt.scatter(df['number_project'],df['left'])
plt.xlabel('number_project')
# Out:
# Text(0.5, 0, 'number_project')

# %%
plt.scatter(df['average_montly_hours'],df['left'])
plt.xlabel('average_montly_hours')
# Out:
# Text(0.5, 0, 'average_montly_hours')

# %%
plt.scatter(df['time_spend_company'],df['left'])
plt.xlabel('time_spend_company')
# Out:
# Text(0.5, 0, 'time_spend_company')

# %%
plt.scatter(df['Work_accident'],df['left'])
plt.xlabel('Work_accident')
# Out:
# Text(0.5, 0, 'Work_accident')

# %%
plt.scatter(df['promotion_last_5years'],df['left'])
plt.xlabel('promotion_last_5years')
# Out:
# Text(0.5, 0, 'promotion_last_5years')

# %%
plt.bar(df['Department'],df['left'])
plt.xlabel('Department')
# Out:
# Text(0.5, 0, 'Department')

# %%
plt.bar(df['salary'],df['left'])
# Out:
# <BarContainer object of 14999 artists>

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
# Out:
# LogisticRegression()

# %%
X=df[['satisfaction_level', 'last_evaluation' , 'average_montly_hours']]
Y=df.left

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(X,Y,test_size=0.05)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.776
